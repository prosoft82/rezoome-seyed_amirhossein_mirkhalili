# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\PC\Desktop\محرومیت\data\labour_force_all_3.csv',low_memory=False)

# %%
df.coli
# Out:
# Index(['Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0', 'pkey', 'NobatAmargiri',
#        'F2_D03', 'F2_D04', 'F2_D05', 'F2_D06', 'F2_D07', 'F2_D15', 'F2_D16',
#        'F2_D17', 'F2_D18', 'F2_D19', 'F3_D01', 'F3_D02', 'F3_D03', 'F3_D04',
#        'F3_D05', 'F3_D06', 'F3_D09', 'F3_D11', 'F3_D13', 'F3_D24', 'F3_D31',
#        'F3_D33', 'F3_D47', 'F3_D49', 'IW_Yearly', 'ActivityStatus', 'year',
#        'household_number', 'cluster_number', 'urban_rural', 'province_code',
#        'sample_year', 'education_group', 'dep_sex', 'dep_urban_rural',
#        'dep_edu', 'dep_age_group', 'deprived'],
#       dtype='object')

# %%
status_counts = df['ActivityStatus'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0       3  905008  59.967346
# 1       1  555288  36.794313
# 2       2   48872   3.238341

# %%
status_counts = df['F2_D04'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0       2  764200  50.637172
# 1       1  744968  49.362828

# %%
status_counts = df['F2_D16'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status    Count    Percent
# 0       1  1270215  84.166574
# 1       2   238953  15.833426

# %%
status_counts = df['urban_rural'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0       1  939326  62.241314
# 1       2  569842  37.758686

# %%
status_counts = df['dep_age_group'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0       2  456738  30.264225
# 1       3  425231  28.176518
# 2       4  379702  25.159691
# 3       1  247497  16.399566

# %%
status_counts = df['F2_D17'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0     1.0  336745  22.313288
# 1     4.0  301110  19.952053
# 2     2.0  284233  18.833755
# 3     6.0  182993  12.125423
# 4     3.0   65737   4.355844
# 5     5.0   52003   3.445806
# 6     7.0   43581   2.887750
# 7     8.0    3535   0.234235
# 8     9.0     278   0.018421

# %%
status_counts = df['F2_D19'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status    Count    Percent
# 0     1.0  1024905  67.911922
# 1     4.0   365756  24.235605
# 2     2.0    94243   6.244699
# 3     3.0    24264   1.607773

# %%
status_counts = df['deprived'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count   Percent
# 0       1  786042  52.08446
# 1       0  723126  47.91554

# %%
status_counts = df['sample_year'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0       1  513381  34.017485
# 1       2  502680  33.308419
# 2       3  493107  32.674096

# %%
status_counts = df['dep_edu'].value_counts()
status_percent = (status_counts / len(df)) * 100
result = pd.DataFrame({
    'Status': status_counts.index,
    'Count': status_counts.values,
    'Percent': status_percent.values
})

print(result)
# Out:
#    Status   Count    Percent
# 0       1  925668  61.336312
# 1       0  583500  38.663688
