# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\PC\Desktop\محرومیت\data\labour_force_all_2.csv',low_memory=False)

# %%
df.shape
# Out:
# (1678970, 43)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1678970 entries, 0 to 1678969
# Data columns (total 43 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   pkey              1678970 non-null  int64
#  1   NobatAmargiri     1678970 non-null  int64
#  2   F2_D03            1678970 non-null  object
#  3   F2_D04            1678970 non-null  int64
#  4   F2_D05            1470585 non-null  object
#  5   F2_D06            1639613 non-null  object
#  6   F2_D07            1678738 non-null  float64
#  7   F2_D15            1678970 non-null  int64
#  8   F2_D16            1678970 non-null  int64
#  9   F2_D17            1438758 non-null  float64
#  10  F2_D18            649524 non-null   object
#  11  F2_D19            1678970 non-null  object
#  12  F3_D01            1678970 non-null  int64
#  13  F3_D02            1188238 non-null  float64
#  14  F3_D03            1176432 non-null  float64
# ...

# %%
# Out:
# pkey                  int64
# NobatAmargiri         int64
# F2_D03               object
# F2_D04                int64
# F2_D05               object
# F2_D06               object
# F2_D07              float64
# F2_D15                int64
# F2_D16                int64
# F2_D17              float64
# F2_D18               object
# F2_D19               object
# F3_D01                int64
# F3_D02              float64
# F3_D03              float64
# F3_D04              float64
# F3_D05              float64
# F3_D06              float64
# F3_D07               object
# F3_D09               object
# F3_D11              float64
# F3_D13               object
# F3_D24               object
# F3_D31              float64
# F3_D33              float64
# F3_D37MAH           float64
# F3_D38               object
# F3_D47              float64
# F3_D49              float64
# IW_Yearly           float64
# ActivityStatus        int64
# year                  int64
# household_number      int64
# ...

# %%
df.head(10)
# Out:
#         pkey  NobatAmargiri F2_D03  F2_D04 F2_D05 F2_D06  F2_D07  F2_D15  \
# 0  125103261              3      1       1     03     47    54.0       2
# 1  125103261              3      2       2     03     58    43.0       2
# 2  125103261              3      3       2     03     80    21.0       1
# 3  125103261              3      3       1     08     85    16.0       1
# 4  125103262              2      1       1     09     71    29.0       2
# 5  125103262              2      2       2     06     73    27.0       2
# 6  125103262              3      1       1     09     71    30.0       2
# 7  125103262              3      2       2     06     73    28.0       2
# 8  125103263              2      1       1     01     62    39.0       2
# 9  125103263              2      2       2     06     62    38.0       2
#
#    F2_D16  F2_D17  ... cluster_number urban_rural  province_code  sample_year  \
# 0       1     8.0  ...             32           1             25            1
# ...

# %%
df.tail(10)
# Out:
#               pkey  NobatAmargiri F2_D03  F2_D04 F2_D05 F2_D06  F2_D07  \
# 1678960  330112679              3      3       1     06     78    24.0
# 1678961  330112679              4      1       1     01     48    55.0
# 1678962  330112679              4      2       2     02     51    52.0
# 1678963  330112679              4      3       1     06     78    25.0
# 1678964  330112680              3      1       1     04     58    45.0
# 1678965  330112680              3      2       2     09     56    46.0
# 1678966  330112680              3      3       1     04     83    20.0
# 1678967  330112680              3      3       1     04     89    14.0
# 1678968  330112680              4      1       1     04     58    45.0
# 1678969  330112680              4      2       2     09     56    46.0
#
#          F2_D15  F2_D16  F2_D17  ... cluster_number urban_rural  \
# 1678960       2       1     2.0  ...            126           1
# ...

# %%
df.describe()
# Out:
#                pkey  NobatAmargiri        F2_D04        F2_D07        F2_D15  \
# count  1.678970e+06   1.678970e+06  1.678970e+06  1.678738e+06  1.678970e+06
# mean   2.135208e+08   2.530269e+00  1.503789e+00  3.963345e+01  1.808015e+00
# std    8.219312e+07   1.113221e+00  4.999858e-01  1.871639e+01  3.938614e-01
# min    1.001002e+08   1.000000e+00  1.000000e+00  1.000000e+01  1.000000e+00
# 25%    1.222097e+08   2.000000e+00  1.000000e+00  2.500000e+01  2.000000e+00
# 50%    2.141011e+08   3.000000e+00  2.000000e+00  3.900000e+01  2.000000e+00
# 75%    3.062184e+08   4.000000e+00  2.000000e+00  5.300000e+01  2.000000e+00
# max    3.302180e+08   4.000000e+00  2.000000e+00  9.900000e+01  2.000000e+00
#
#              F2_D16        F2_D17        F3_D01        F3_D02        F3_D03  \
# count  1.678970e+06  1.438758e+06  1.678970e+06  1.188238e+06  1.176432e+06
# mean   1.143071e+00  2.948485e+00  1.707718e+00  1.990064e+00  1.975143e+00
# ...

# %%
df['F2_D04'].value_counts().sort_values()
# Out:
# F2_D07
# 98.0       95
# 99.0      100
# 97.0      164
# 96.0      262
# 95.0      318
#         ...
# 40.0    35700
# 35.0    36388
# 37.0    36504
# 36.0    36710
# 38.0    37208
# Name: count, Length: 90, dtype: int64

# %%
df['F2_D07'].value_counts().sort_values()
# Out:
# F2_D07
# 98.0       95
# 99.0      100
# 97.0      164
# 96.0      262
# 95.0      318
#         ...
# 40.0    35700
# 35.0    36388
# 37.0    36504
# 36.0    36710
# 38.0    37208
# Name: count, Length: 90, dtype: int64

# %%
df['F2_D17'].value_counts().sort_values()
# Out:
# F2_D17
# 9.0       301
# 8.0      3535
# 7.0     43583
# 5.0     52006
# 3.0     66262
# 6.0    183006
# 4.0    301123
# 2.0    355800
# 1.0    433142
# Name: count, dtype: int64

# %%
df['dep_sex'].value_counts().sort_values()
# Out:
# dep_sex
# 0    833124
# 1    845846
# Name: count, dtype: int64

# %%
df['dep_urban_rural'].value_counts().sort_values()
# Out:
# dep_urban_rural
# 1     640322
# 0    1038648
# Name: count, dtype: int64

# %%
df['dep_edu'].value_counts().sort_values()
# Out:
# dep_edu
# 0     583554
# 1    1095416
# Name: count, dtype: int64

# %%
df['deprived'].value_counts().sort_values()
# Out:
# deprived
# 1    789776
# 0    889194
# Name: count, dtype: int64

# %%
df['dep_age_group'].value_counts().sort_values()
# Out:
# dep_age_group
# 4    379941
# 1    417023
# 3    425248
# 2    456758
# Name: count, dtype: int64

# %%
df_new = df[df['F2_D07'] >= 15 ]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1509233 entries, 0 to 1678969
# Data columns (total 43 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   pkey              1509233 non-null  int64
#  1   NobatAmargiri     1509233 non-null  int64
#  2   F2_D03            1509233 non-null  object
#  3   F2_D04            1509233 non-null  int64
#  4   F2_D05            1320423 non-null  object
#  5   F2_D06            1475087 non-null  object
#  6   F2_D07            1509233 non-null  float64
#  7   F2_D15            1509233 non-null  int64
#  8   F2_D16            1509233 non-null  int64
#  9   F2_D17            1270273 non-null  float64
#  10  F2_D18            648995 non-null   object
#  11  F2_D19            1509233 non-null  object
#  12  F3_D01            1509233 non-null  int64
#  13  F3_D02            1019012 non-null  float64
#  14  F3_D03            1007248 non-null  float64
# ...

# %%
df_new.drop(columns=['F3_D37MAH','F3_D38','F3_D07',])
# Out:
#               pkey  NobatAmargiri F2_D03  F2_D04 F2_D05 F2_D06  F2_D07  \
# 0        125103261              3      1       1     03     47    54.0
# 1        125103261              3      2       2     03     58    43.0
# 2        125103261              3      3       2     03     80    21.0
# 3        125103261              3      3       1     08     85    16.0
# 4        125103262              2      1       1     09     71    29.0
# ...            ...            ...    ...     ...    ...    ...     ...
# 1678964  330112680              3      1       1     04     58    45.0
# 1678965  330112680              3      2       2     09     56    46.0
# 1678966  330112680              3      3       1     04     83    20.0
# 1678968  330112680              4      1       1     04     58    45.0
# 1678969  330112680              4      2       2     09     56    46.0
#
#          F2_D15  F2_D16  F2_D17  ... cluster_number urban_rural  \
# ...

# %%
df_new.to_csv(r'C:\Users\PC\Desktop\محرومیت\data\labour_force_all_3.csv')
