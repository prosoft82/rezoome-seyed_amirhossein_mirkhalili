# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\PC\Desktop\محرومیت\data\labour_force_all_3.csv',low_memory=False)

# %%
df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, pkey, NobatAmargiri, F2_D03, F2_D04, F2_D05, F2_D06, F2_D07, F2_D15, F2_D16, F2_D17, F2_D18, F2_D19, F3_D01, F3_D02, F3_D03, F3_D04, F3_D05, F3_D06, F3_D07, F3_D09, F3_D11, F3_D13, F3_D24, F3_D31, F3_D33, F3_D37MAH, F3_D38, F3_D47, F3_D49, IW_Yearly, ActivityStatus, year, household_number, cluster_number, urban_rural, province_code, sample_year, education_group, dep_sex, dep_urban_rural, dep_edu, dep_age_group, deprived]
# Index: []
#
# [0 rows x 44 columns]

# %%
df.drop_duplicates()
# Out:
#          Unnamed: 0       pkey  NobatAmargiri F2_D03  F2_D04 F2_D05  F2_D06  \
# 0                 0  125103261              3      1       1     03    47.0
# 1                 1  125103261              3      2       2     03    58.0
# 2                 2  125103261              3      3       2     03    80.0
# 3                 3  125103261              3      3       1     08    85.0
# 4                 4  125103262              2      1       1     09    71.0
# ...             ...        ...            ...    ...     ...    ...     ...
# 1509228     1678964  330112680              3      1       1     04    58.0
# 1509229     1678965  330112680              3      2       2     09    56.0
# 1509230     1678966  330112680              3      3       1     04    83.0
# 1509231     1678968  330112680              4      1       1     04    58.0
# 1509232     1678969  330112680              4      2       2     09    56.0
#
# ...

# %%
df['F2_D19'] = pd.to_numeric(df['F2_D19'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1509233 entries, 0 to 1509232
# Data columns (total 44 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1509233 non-null  int64
#  1   pkey              1509233 non-null  int64
#  2   NobatAmargiri     1509233 non-null  int64
#  3   F2_D03            1509233 non-null  object
#  4   F2_D04            1509233 non-null  int64
#  5   F2_D05            1320423 non-null  object
#  6   F2_D06            1475087 non-null  float64
#  7   F2_D07            1509233 non-null  float64
#  8   F2_D15            1509233 non-null  int64
#  9   F2_D16            1509233 non-null  int64
#  10  F2_D17            1270273 non-null  float64
#  11  F2_D18            648995 non-null   object
#  12  F2_D19            1509168 non-null  float64
#  13  F3_D01            1509233 non-null  int64
#  14  F3_D02            1019012 non-null  float64
# ...

# %%
df_new1 = df.dropna(subset=['F2_D19'])

# %%
df_new.to_csv(r'C:\Users\PC\Desktop\محرومیت\data\labour_force_all_3.csv')

# %%
df_new = df.drop(columns=['F3_D37MAH','F3_D38','F3_D07'])
